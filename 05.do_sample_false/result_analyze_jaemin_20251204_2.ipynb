# %%
import pandas as pd
import re
import json


input_path = "jaemin_20251204_2_.txt"  

with open(input_path, "r", encoding="utf-8") as f:
    text = f.read()

pattern = r"(\/[^\n]+\/(normal|abnormal)\/[^\n]+)\s*[\s\S]*?(?:```json\s*([\s\S]*?)\s*```|(\{[\s\S]*?\}))"
matches = re.findall(pattern, text, re.DOTALL)

rows = []

for match in matches:
    
    path, truth, json_block, json_raw = match
    json_str = json_block if json_block else json_raw
    
    try:
        data = json.loads(json_str)

        is_scam = bool(data.get("is_scam"))

        if (is_scam and truth == "abnormal") or (not is_scam and truth == "normal"):
            result = True
        else:
            result = False

        rows.append({
            "filename": path.split("/")[-1].strip(),
            "truth": truth,
            "is_scam": data.get("is_scam"),
            "result": result,
            "is_correct": data.get("is_scam"),
            "confidence": data.get("confidence"),
            "risk": data.get("risk"),
            "evidence": "; ".join(data.get("evidence", [])),
            "explanation": data.get("explanation"),            
        })
    except json.JSONDecodeError as e:
        print(f"JSON 파싱 오류 발생 ({path}): {e}")

df = pd.DataFrame(rows, columns=["filename", "truth", "is_scam", "result", "confidence", "risk", "evidence", "explanation"])

output_path = "scam_results.csv"
df.to_csv(output_path, index=False, encoding="utf-8-sig")

print(f"CSV 파일 생성 완료: {output_path}")
print(df)
# Out:
# CSV 파일 생성 완료: scam_results.csv
#     filename     truth  is_scam  result  confidence  risk  \
# 0   0025.mp4    normal     True   False        0.90  high
# 1   0011.mp4    normal    False    True        0.25   low
# 2   0024.mp4    normal    False    True        0.25   low
# 3   0004.mp4    normal    False    True        0.25   low
# 4   0001.mp4    normal    False    True        0.15   low
# 5   0006.mp4    normal    False    True        0.25   low
# 6   0016.mp4    normal    False    True        0.25   low
# 7   0005.mp4    normal     True   False        0.92  high
# 8   0018.mp4    normal    False    True        0.15   low
# 9   0023.mp4    normal    False    True        0.15   low
# 10  0007.mp4    normal    False    True        0.15   low
# 11  0014.mp4    normal    False    True        0.35   low
# 12  0021.mp4    normal    False    True        0.25   low
# 13  0027.mp4    normal     True   False        0.92  high
# 14  0012.mp4    normal    False    True        0.15   low
# 15  0010.mp4    normal    False    True        0.25   low
# 16  0015.mp4    normal    False    True        0.25   low
# 17  0003.mp4    normal    False    True        0.15   low
# 18  0002.mp4    normal    False    True        0.25   low
# 19  0022.mp4    normal    False    True        0.35   low
# 20  0019.mp4    normal    False    True        0.15   low
# 21  0008.mp4    normal    False    True        0.25   low
# 22  0026.mp4    normal     True   False        0.90  high
# 23  0000.mp4    normal    False    True        0.25   low
# 24  0009.mp4    normal    False    True        0.15   low
# 25  0013.mp4    normal    False    True        0.15   low
# 26  0020.mp4    normal    False    True        0.25   low
# 27  0017.mp4    normal    False    True        0.15   low
# 28  0025.mp4  abnormal    False   False        0.25   low
# 29  0011.mp4  abnormal     True    True        0.92  high
# 30  0034.mp4  abnormal     True    True        0.92  high
# 31  0029.mp4  abnormal     True    True        0.90  high
# 32  0033.mp4  abnormal     True    True        0.95  high
# 33  0004.mp4  abnormal    False   False        0.15   low
# 34  0035.mp4  abnormal     True    True        0.95  high
# 35  0001.mp4  abnormal     True    True        0.90  high
# 36  0006.mp4  abnormal     True    True        0.90  high
# 37  0016.mp4  abnormal     True    True        0.90  high
# 38  0005.mp4  abnormal    False   False        0.35   low
# 39  0018.mp4  abnormal    False   False        0.35   low
# 40  0007.mp4  abnormal    False   False        0.35   low
# 41  0014.mp4  abnormal     True    True        0.95  high
# 42  0031.mp4  abnormal    False   False        0.35   low
# 43  0012.mp4  abnormal    False   False        0.25   low
# 44  0010.mp4  abnormal     True    True        0.90  high
# 45  0003.mp4  abnormal     True    True        0.95  high
# 46  0002.mp4  abnormal     True    True        0.90  high
# 47  0030.mp4  abnormal    False   False        0.35   low
# 48  0008.mp4  abnormal    False   False        0.25   low
# 49  0026.mp4  abnormal     True    True        0.92  high
# 50  0032.mp4  abnormal     True    True        0.90  high
# 51  0000.mp4  abnormal    False   False        0.35   low
# 52  0009.mp4  abnormal    False   False        0.15   low
# 53  0013.mp4  abnormal    False   False        0.35   low
# 54  0017.mp4  abnormal     True    True        0.85   mid
#
#                                              evidence  \
# 0                               우버 택시 50% 헤택; 그시절택시요금
# 1                                할바하게 되면 하는 것; 이어폰 빼고
# 2   Normal cereal consumption; Product demonstrati...
# 3   Normal job-related content; No explicit reques...
# 4   Normal job-related content; No explicit reques...
# 5                                                  ;
# 6                                         고작한 장난을 한 번
# 7                           knife; customer complaint
# 8                                                한번씩만
# 9                     nonstick coating; multi-cookpan
# 10                              7일간 단기알바 만으로 100만원 벌기
# 11                                 아아 음료만이; 레몬에어드 음료재
# 12                                                 ;
# 13               guaranteed or outsized/rapid profits
# 14                                      알바 안 해본 연예인 특
# 15                                                 ;
# 16                                         T1 x Speak
# 17             Normal conversation; Humorous exchange
# 18                                    MBTI bill; INFP
# 19                                     NEW 다이슨 슈퍼소닉 r
# 20                   End of day liquid nitrogen dumps
# 21        Normal job experience; Personal reflections
# 22                              우버 택시 50% 헤택; 그시절택시요금
# 23                                요즘 MZ들 알바 면접 불쾌duck
# 24  Normal warehouse operations; Scanning packages...
# 25                                   banana milkshake
# 26                               한강에서 마고까지; 한강에서 마고까지
# 27                              이대생이 시험지를 반대로 집어두는 이유
# 28                     recommendation code; app usage
# 29                                      银行账号; 能听懂我说话吧
# 30  guaranteed or outsized/rapid profits; external...
# 31  100% 보장된 나무, 코인 수확 시작됐다; 8월 1일부터 9월 30일까지, 단 두 달간
# 32  300% guaranteed profit; QR code to join a Tele...
# 33  Various sandals displayed on wooden shelves; H...
# 34  investment/financial lures; guaranteed or outs...
# 35               guaranteed profits; external funnels
# 36                                      50만 원씩; 아르바이트
# 37                                          2,500,000
# 38            가상화폐 구매대행 모집; 한 달이면 마음에 드는 차를 살 수 있습니다.
# 39                                          다음message
# 40                        사람들에게 공과 희망을; 볼어 봐주는 사이비 교수
# 41       guaranteed fines; requests for personal data
# 42                                                 ;
# 43               Gucci jeans; Various sizes available
# 44                     비밀번호를布拉 주십시오; ??? : 누가 봐도 구라잖아
# 45  investment/financial lures; guaranteed or outs...
# 46  guaranteed or outsized/rapid profits; external...
# 47                                      전천조 고백 나는 사기꾼
# 48  Normal classroom setting; Educational or train...
# 49                                  이상한 익명의 전화; 보이스피싱
# 50  guaranteed or outsized/rapid profits; external...
# 51    고객님께서 주문하신 남성 패딩 배송전实时사입니다; 예쁜 패딩 필요하신 분们 물어주시면
# 52            AI-generated doctor; fake advertisement
# 53                                   VIP席 FLOOR; F2구역
# 54  Requests for deposits, wallet transfers, fees,...
#
#                                           explanation
# 0   The video contains strong scam indicators such...
# 1   The video appears to be a humorous or instruct...
# 2   The video shows a normal product usage scenari...
# 3   The video appears to be about a part-time job ...
# 4   The video discusses the challenges of part-tim...
# 5   The video does not contain any strong or direc...
# 6   The video appears to be a demonstration of sol...
# 7   The video shows a customer repeatedly asking f...
# 8   The video appears to be a review or recommenda...
# 9   The video describes the features of a nonstick...
# 10  The video appears to be about a person's exper...
# 11  The video appears to be a tutorial or demonstr...
# 12  The video describes a job as a '병원동행내지' (Hospi...
# 13  The video promises a significant increase in c...
# 14  The video appears to be a humorous or light-he...
# 15  The video description does not contain any str...
# 16  The video appears to be a promotional or infor...
# 17  The video appears to be a humorous or satirica...
# 18  The video appears to be a humorous or informat...
# 19  The video appears to be a promotional advertis...
# 20  The video shows a nurse using liquid nitrogen ...
# 21  The video appears to be a personal reflection ...
# 22  The video contains strong scam indicators such...
# 23  The video appears to be a humorous or satirica...
# 24  The video shows typical activities in a logist...
# 25  The video shows the preparation of a banana mi...
# 26  The video describes a ferry ride and does not ...
# 27  The video provides a step-by-step guide on how...
# 28  The video appears to be a normal informational...
# 29  The video contains a scammer asking for bank a...
# 30  The video promises significant returns and inc...
# 31  The video contains strong scam indicators such...
# 32  The description contains explicit profit guara...
# 33  The video shows various styles of sandals in d...
# 34  The video mentions a target of '32,000 won' an...
# 35  The video contains strong indicators of a fina...
# 36  The description mentions a large sum of money ...
# 37  The presence of a large monetary figure withou...
# 38  The video describes a cryptocurrency purchase ...
# 39  The content appears to be a normal chat conver...
# 40  The video shows a demonstration of self-defens...
# 41  The video contains multiple strong signals of ...
# 42  The description does not contain any strong or...
# 43  The video appears to be a normal product prese...
# 44  The video shows a screen with instructions to ...
# 45  The video promotes a significant potential pro...
# 46  The video advertises potential earnings of up ...
# 47  The video appears to be a warning or education...
# 48  The video depicts a normal educational or trai...
# 49  The conversation involves a scammer impersonat...
# 50  The video advertises guaranteed financial retu...
# 51  The video description mentions a customer's or...
# 52  The video features AI-generated characters and...
# 53  The video appears to be a ticket purchase inte...
# 54  The description includes a request to transfer...

# %%
df.groupby(["truth", "result"]).agg({"filename":"count"})
# Out:
#                  filename
# truth    result
# abnormal False         12
#          True          15
# normal   False          4
#          True          24

# %%
df[df['result']==True]
# Out:
#     filename     truth  is_scam  result  confidence  risk  \
# 1   0011.mp4    normal    False    True        0.25   low
# 2   0024.mp4    normal    False    True        0.25   low
# 3   0004.mp4    normal    False    True        0.25   low
# 4   0001.mp4    normal    False    True        0.15   low
# 5   0006.mp4    normal    False    True        0.25   low
# 6   0016.mp4    normal    False    True        0.25   low
# 8   0018.mp4    normal    False    True        0.15   low
# 9   0023.mp4    normal    False    True        0.15   low
# 10  0007.mp4    normal    False    True        0.15   low
# 11  0014.mp4    normal    False    True        0.35   low
# 12  0021.mp4    normal    False    True        0.25   low
# 14  0012.mp4    normal    False    True        0.15   low
# 15  0010.mp4    normal    False    True        0.25   low
# 16  0015.mp4    normal    False    True        0.25   low
# 17  0003.mp4    normal    False    True        0.15   low
# 18  0002.mp4    normal    False    True        0.25   low
# 19  0022.mp4    normal    False    True        0.35   low
# 20  0019.mp4    normal    False    True        0.15   low
# 21  0008.mp4    normal    False    True        0.25   low
# 23  0000.mp4    normal    False    True        0.25   low
# 24  0009.mp4    normal    False    True        0.15   low
# 25  0013.mp4    normal    False    True        0.15   low
# 26  0020.mp4    normal    False    True        0.25   low
# 27  0017.mp4    normal    False    True        0.15   low
# 29  0011.mp4  abnormal     True    True        0.92  high
# 30  0034.mp4  abnormal     True    True        0.92  high
# 31  0029.mp4  abnormal     True    True        0.90  high
# 32  0033.mp4  abnormal     True    True        0.95  high
# 34  0035.mp4  abnormal     True    True        0.95  high
# 35  0001.mp4  abnormal     True    True        0.90  high
# 36  0006.mp4  abnormal     True    True        0.90  high
# 37  0016.mp4  abnormal     True    True        0.90  high
# 41  0014.mp4  abnormal     True    True        0.95  high
# 44  0010.mp4  abnormal     True    True        0.90  high
# 45  0003.mp4  abnormal     True    True        0.95  high
# 46  0002.mp4  abnormal     True    True        0.90  high
# 49  0026.mp4  abnormal     True    True        0.92  high
# 50  0032.mp4  abnormal     True    True        0.90  high
# 54  0017.mp4  abnormal     True    True        0.85   mid
#
#                                              evidence  \
# 1                                할바하게 되면 하는 것; 이어폰 빼고
# 2   Normal cereal consumption; Product demonstrati...
# 3   Normal job-related content; No explicit reques...
# 4   Normal job-related content; No explicit reques...
# 5                                                  ;
# 6                                         고작한 장난을 한 번
# 8                                                한번씩만
# 9                     nonstick coating; multi-cookpan
# 10                              7일간 단기알바 만으로 100만원 벌기
# 11                                 아아 음료만이; 레몬에어드 음료재
# 12                                                 ;
# 14                                      알바 안 해본 연예인 특
# 15                                                 ;
# 16                                         T1 x Speak
# 17             Normal conversation; Humorous exchange
# 18                                    MBTI bill; INFP
# 19                                     NEW 다이슨 슈퍼소닉 r
# 20                   End of day liquid nitrogen dumps
# 21        Normal job experience; Personal reflections
# 23                                요즘 MZ들 알바 면접 불쾌duck
# 24  Normal warehouse operations; Scanning packages...
# 25                                   banana milkshake
# 26                               한강에서 마고까지; 한강에서 마고까지
# 27                              이대생이 시험지를 반대로 집어두는 이유
# 29                                      银行账号; 能听懂我说话吧
# 30  guaranteed or outsized/rapid profits; external...
# 31  100% 보장된 나무, 코인 수확 시작됐다; 8월 1일부터 9월 30일까지, 단 두 달간
# 32  300% guaranteed profit; QR code to join a Tele...
# 34  investment/financial lures; guaranteed or outs...
# 35               guaranteed profits; external funnels
# 36                                      50만 원씩; 아르바이트
# 37                                          2,500,000
# 41       guaranteed fines; requests for personal data
# 44                     비밀번호를布拉 주십시오; ??? : 누가 봐도 구라잖아
# 45  investment/financial lures; guaranteed or outs...
# 46  guaranteed or outsized/rapid profits; external...
# 49                                  이상한 익명의 전화; 보이스피싱
# 50  guaranteed or outsized/rapid profits; external...
# 54  Requests for deposits, wallet transfers, fees,...
#
#                                           explanation
# 1   The video appears to be a humorous or instruct...
# 2   The video shows a normal product usage scenari...
# 3   The video appears to be about a part-time job ...
# 4   The video discusses the challenges of part-tim...
# 5   The video does not contain any strong or direc...
# 6   The video appears to be a demonstration of sol...
# 8   The video appears to be a review or recommenda...
# 9   The video describes the features of a nonstick...
# 10  The video appears to be about a person's exper...
# 11  The video appears to be a tutorial or demonstr...
# 12  The video describes a job as a '병원동행내지' (Hospi...
# 14  The video appears to be a humorous or light-he...
# 15  The video description does not contain any str...
# 16  The video appears to be a promotional or infor...
# 17  The video appears to be a humorous or satirica...
# 18  The video appears to be a humorous or informat...
# 19  The video appears to be a promotional advertis...
# 20  The video shows a nurse using liquid nitrogen ...
# 21  The video appears to be a personal reflection ...
# 23  The video appears to be a humorous or satirica...
# 24  The video shows typical activities in a logist...
# 25  The video shows the preparation of a banana mi...
# 26  The video describes a ferry ride and does not ...
# 27  The video provides a step-by-step guide on how...
# 29  The video contains a scammer asking for bank a...
# 30  The video promises significant returns and inc...
# 31  The video contains strong scam indicators such...
# 32  The description contains explicit profit guara...
# 34  The video mentions a target of '32,000 won' an...
# 35  The video contains strong indicators of a fina...
# 36  The description mentions a large sum of money ...
# 37  The presence of a large monetary figure withou...
# 41  The video contains multiple strong signals of ...
# 44  The video shows a screen with instructions to ...
# 45  The video promotes a significant potential pro...
# 46  The video advertises potential earnings of up ...
# 49  The conversation involves a scammer impersonat...
# 50  The video advertises guaranteed financial retu...
# 54  The description includes a request to transfer...

# %%
df[df['result']==False]
# Out:
#     filename     truth  is_scam  result  confidence  risk  \
# 0   0025.mp4    normal     True   False        0.90  high
# 7   0005.mp4    normal     True   False        0.92  high
# 13  0027.mp4    normal     True   False        0.92  high
# 22  0026.mp4    normal     True   False        0.90  high
# 28  0025.mp4  abnormal    False   False        0.25   low
# 33  0004.mp4  abnormal    False   False        0.15   low
# 38  0005.mp4  abnormal    False   False        0.35   low
# 39  0018.mp4  abnormal    False   False        0.35   low
# 40  0007.mp4  abnormal    False   False        0.35   low
# 42  0031.mp4  abnormal    False   False        0.35   low
# 43  0012.mp4  abnormal    False   False        0.25   low
# 47  0030.mp4  abnormal    False   False        0.35   low
# 48  0008.mp4  abnormal    False   False        0.25   low
# 51  0000.mp4  abnormal    False   False        0.35   low
# 52  0009.mp4  abnormal    False   False        0.15   low
# 53  0013.mp4  abnormal    False   False        0.35   low
#
#                                              evidence  \
# 0                               우버 택시 50% 헤택; 그시절택시요금
# 7                           knife; customer complaint
# 13               guaranteed or outsized/rapid profits
# 22                              우버 택시 50% 헤택; 그시절택시요금
# 28                     recommendation code; app usage
# 33  Various sandals displayed on wooden shelves; H...
# 38            가상화폐 구매대행 모집; 한 달이면 마음에 드는 차를 살 수 있습니다.
# 39                                          다음message
# 40                        사람들에게 공과 희망을; 볼어 봐주는 사이비 교수
# 42                                                 ;
# 43               Gucci jeans; Various sizes available
# 47                                      전천조 고백 나는 사기꾼
# 48  Normal classroom setting; Educational or train...
# 51    고객님께서 주문하신 남성 패딩 배송전实时사입니다; 예쁜 패딩 필요하신 분们 물어주시면
# 52            AI-generated doctor; fake advertisement
# 53                                   VIP席 FLOOR; F2구역
#
#                                           explanation
# 0   The video contains strong scam indicators such...
# 7   The video shows a customer repeatedly asking f...
# 13  The video promises a significant increase in c...
# 22  The video contains strong scam indicators such...
# 28  The video appears to be a normal informational...
# 33  The video shows various styles of sandals in d...
# 38  The video describes a cryptocurrency purchase ...
# 39  The content appears to be a normal chat conver...
# 40  The video shows a demonstration of self-defens...
# 42  The description does not contain any strong or...
# 43  The video appears to be a normal product prese...
# 47  The video appears to be a warning or education...
# 48  The video depicts a normal educational or trai...
# 51  The video description mentions a customer's or...
# 52  The video features AI-generated characters and...
# 53  The video appears to be a ticket purchase inte...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score, confusion_matrix, ConfusionMatrixDisplay

# abnormal = positive class
df['y_true'] = df['truth'].apply(lambda x: 1 if x=='abnormal' else 0)
y_true = df['y_true'].values
y_scores = df['confidence'].values

# Precision-Recall + AP
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
ap = average_precision_score(y_true, y_scores)
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"AP (mAP): {ap:.4f}")

# PR curve 시각화
plt.figure(figsize=(6,6))
plt.plot(recall, precision, marker='.', label=f'AP={ap:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

# 최적 threshold 선택 (F1 최대)
f1_scores = 2*precision*recall/(precision+recall+1e-8)
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
print(f"Optimal threshold (F1 max): {best_threshold:.2f}")

# Confusion matrix
y_pred = (y_scores >= best_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred, labels=[1,0])
disp = ConfusionMatrixDisplay(cm, display_labels=['abnormal', 'normal'])
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix @ threshold={best_threshold:.2f}')
plt.show()
# Out:
# Precision: [0.49090909 0.58139535 0.78571429 0.78947368 0.77777778 0.77777778
#  1.         1.        ]
# Recall: [1.         0.92592593 0.81481481 0.55555556 0.51851852 0.25925926
#  0.14814815 0.        ]
# AP (mAP): 0.7701
# Optimal threshold (F1 max): 0.35
