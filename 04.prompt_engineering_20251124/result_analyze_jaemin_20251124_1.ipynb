# %%
import pandas as pd
import re
import json


input_path = "jaemin_20251124_1_.txt"  

with open(input_path, "r", encoding="utf-8") as f:
    text = f.read()

pattern = r"(\/[^\n]+\/(normal|abnormal)\/[^\n]+)\s*[\s\S]*?(?:```json\s*([\s\S]*?)\s*```|(\{[\s\S]*?\}))"
matches = re.findall(pattern, text, re.DOTALL)

rows = []

for match in matches:
    
    path, truth, json_block, json_raw = match
    json_str = json_block if json_block else json_raw
    
    try:
        data = json.loads(json_str)

        is_scam = bool(data.get("is_scam"))

        if (is_scam and truth == "abnormal") or (not is_scam and truth == "normal"):
            result = True
        else:
            result = False

        rows.append({
            "filename": path.split("/")[-1].strip(),
            "truth": truth,
            "is_scam": data.get("is_scam"),
            "result": result,
            "is_correct": data.get("is_scam"),
            "confidence": data.get("confidence"),
            "risk": data.get("risk"),
            "evidence": "; ".join(data.get("evidence", [])),
            "explanation": data.get("explanation"),            
        })
    except json.JSONDecodeError as e:
        print(f"JSON 파싱 오류 발생 ({path}): {e}")

df = pd.DataFrame(rows, columns=["filename", "truth", "is_scam", "result", "confidence", "risk", "evidence", "explanation"])

output_path = "scam_results.csv"
df.to_csv(output_path, index=False, encoding="utf-8-sig")

print(f"CSV 파일 생성 완료: {output_path}")
print(df)
# Out:
# CSV 파일 생성 완료: scam_results.csv
#     filename     truth  is_scam  result  confidence  risk  \
# 0   0025.mp4    normal     True   False        0.92  high
# 1   0011.mp4    normal    False    True        0.75   low
# 2   0024.mp4    normal    False    True        0.75   low
# 3   0004.mp4    normal    False    True        0.25   low
# 4   0001.mp4    normal    False    True        0.75   low
# 5   0006.mp4    normal    False    True        0.35   low
# 6   0016.mp4    normal    False    True        0.15   low
# 7   0005.mp4    normal    False    True        0.15   low
# 8   0018.mp4    normal    False    True        0.75   low
# 9   0023.mp4    normal    False    True        0.75   low
# 10  0007.mp4    normal    False    True        0.15   low
# 11  0014.mp4    normal    False    True        0.75   low
# 12  0021.mp4    normal    False    True        0.75   low
# 13  0027.mp4    normal    False    True        0.90   low
# 14  0012.mp4    normal    False    True        0.35   low
# 15  0010.mp4    normal    False    True        0.25   low
# 16  0015.mp4    normal    False    True        0.25   low
# 17  0003.mp4    normal    False    True        0.15   low
# 18  0002.mp4    normal    False    True        0.35   low
# 19  0022.mp4    normal    False    True        0.75   low
# 20  0019.mp4    normal    False    True        0.75   low
# 21  0008.mp4    normal    False    True        0.15   low
# 22  0026.mp4    normal     True   False        0.92  high
# 23  0000.mp4    normal    False    True        0.25   low
# 24  0009.mp4    normal    False    True        0.15   low
# 25  0013.mp4    normal    False    True        0.75   low
# 26  0020.mp4    normal    False    True        0.75   low
# 27  0017.mp4    normal    False    True        0.15   low
# 28  0025.mp4  abnormal    False   False        0.35   low
# 29  0011.mp4  abnormal     True    True        0.92  high
# 30  0034.mp4  abnormal     True    True        0.95  high
# 31  0029.mp4  abnormal     True    True        0.92  high
# 32  0033.mp4  abnormal     True    True        0.95  high
# 33  0004.mp4  abnormal    False   False        0.75   low
# 34  0035.mp4  abnormal    False   False        0.15   low
# 35  0001.mp4  abnormal     True    True        0.92  high
# 36  0006.mp4  abnormal     True    True        0.85  high
# 37  0016.mp4  abnormal    False   False        0.35   low
# 38  0005.mp4  abnormal    False   False        0.35   low
# 39  0018.mp4  abnormal    False   False        0.25   low
# 40  0007.mp4  abnormal    False   False        0.75   low
# 41  0014.mp4  abnormal     True    True        0.92  high
# 42  0031.mp4  abnormal    False   False        0.35   low
# 43  0012.mp4  abnormal    False   False        0.75   low
# 44  0010.mp4  abnormal     True    True        0.92  high
# 45  0003.mp4  abnormal     True    True        0.95  high
# 46  0002.mp4  abnormal     True    True        0.92  high
# 47  0030.mp4  abnormal    False   False        0.75   low
# 48  0008.mp4  abnormal    False   False        0.35   low
# 49  0026.mp4  abnormal     True    True        0.92  high
# 50  0032.mp4  abnormal     True    True        0.92  high
# 51  0000.mp4  abnormal    False   False        0.35   low
# 52  0009.mp4  abnormal     True    True        0.92  high
# 53  0013.mp4  abnormal     True    True        0.92  high
# 54  0017.mp4  abnormal     True    True        0.85  high
#
#                                              evidence  \
# 0                               우버 택시 50% 헤택; 그시절택시요금
# 1               할바하게 되면 하는 것; 이어폰 빼고; 결제카드는; 이걸로 해주세요
# 2   New product innovation; Innovative solution fo...
# 3   Must buy before [date] statements; Suspicious ...
# 4                              2025년 최저임금 인상 확정; 주휴스담
# 5                                          50대 근판리얼후기
# 6            Rubik's cube solving; casual interaction
# 7   No explicit requests for payment or data; No d...
# 8                                                한번씩만
# 9                    non-stick coating; multi-cookpan
# 10                              7일간 단기알바 만으로 100만원 벌기
# 11  Guaranteed or outsized returns/profits; Direct...
# 12  Certification of qualification; Online study a...
# 13  280 calorie ramen; 250 calorie Boston cream; 1...
# 14                                이托리들이; 이거 그iddy한 데요
# 15                                      고객을 만족시켜야 합니다
# 16                                         T1 x Speak
# 17  No explicit requests for payment or data; No d...
# 18                                    MBTI bill; INFP
# 19        NEW 다이슨 슈퍼소닉 r; 다이스의 가장 가벼고, 가장 경력한? 해어트라이어
# 20  End of day liquid nitrogen dumps; Liquid nitro...
# 21                         CURPANG ALBA; CURPANG ALBA
# 22                              우버 택시 50% 헤택; 그시절택시요금
# 23                                         무자로 보내 주셔~
# 24  Coupaing delivery; Scanning packages; Vending ...
# 25               banana milkshake; Compose Coffee cup
# 26                         Hangang Bus; Grand Opening
# 27                              이대생이 시험지를 반대로 집어두는 이유
# 28                     recommendation code; app usage
# 29                                      银行账号; 能听懂我说话吧
# 30  guaranteed or outsized returns; direct request...
# 31  100% guaranteed profit; external contact via K...
# 32  300% guaranteed profit; QR code to join a Tele...
# 33           Various sandals displayed; Handbag shown
# 34     10월 전에는 꼭 사라; 보통주 (06★★★) 현제가: 1400 최고가: 32000
# 35                          ohoo nasda injeong; 6月14일
# 36                                      50만 원씩; 아르바이트
# 37                                          2,500,000
# 38            가상화폐 구매대행 모집; 한 달이면 마음에 드는 차를 살 수 있습니다.
# 39                                          다음message
# 40                       사람들에게 공과 희망을; 불어 놓아주는 사이비 교수
# 41  guaranteed or outsized returns/profits; direct...
# 42                                 아이디Patrick; 게임성공추천
# 43                       Gucci brand; product details
# 44                guaranteed return; external contact
# 45  guaranteed or outsized returns; direct request...
# 46  guaranteed or outsized returns/profits; extern...
# 47                        전천조 고백 나는 사기꾼; 별 걸 다 했어네 진짜
# 48                  classroom setting; group activity
# 49                                         柏林市長; 特別部隊
# 50               guaranteed returns; external contact
# 51    고객님께서 주문하신 남성 패딩 배송전实时사입니다; 예쁜 패딩 필요하신 분们 물어주시면
# 52            AI-generated doctor; fake advertisement
# 53               Must buy before June 6th; VIP席 FLOOR
# 54   Must buy before [date]; Install app/site to earn
#
#                                           explanation
# 0   The video contains strong scam signals, such a...
# 1   The video appears to be a humorous or instruct...
# 2   The video describes a new, innovative way to c...
# 3   The video appears educational, focusing on a j...
# 4   The video discusses the minimum wage increase ...
# 5   The video description contains a personal stor...
# 6   The video shows a person casually solving a Ru...
# 7   The video appears to be a normal interaction i...
# 8   The video description does not contain any exp...
# 9   The video describes the features of a non-stic...
# 10  The video description does not contain any str...
# 11  The video describes a process of making drinks...
# 12  The video describes a certification process fo...
# 13  The video shows a person eating various meals,...
# 14  The video features a humorous interaction betw...
# 15  The video description contains a message about...
# 16  The video features a collaboration between T1 ...
# 17  The video appears to be a humorous skit from '...
# 18  The video appears to be an educational or info...
# 19  The video describes a new Dyson product withou...
# 20  The video describes the use of liquid nitrogen...
# 21  The video appears to be a personal account of ...
# 22  The video contains strong scam signals, such a...
# 23  The video description contains a request to se...
# 24  The video shows a typical day at an e-commerce...
# 25  The video shows the preparation of a banana mi...
# 26  The video describes a public transportation se...
# 27  The video provides a step-by-step guide on how...
# 28  The video shows a person discussing an app and...
# 29  The video contains a direct request for bank a...
# 30  The video contains strong indicators of a scam...
# 31  The video contains strong scam signals such as...
# 32  The description contains explicit profit guara...
# 33  The video shows a display of various sandals a...
# 34  The video description contains typical stock m...
# 35  The video contains strong scam signals such as...
# 36  The video description mentions a digital job t...
# 37  The video contains a large number '2,500,000' ...
# 38  The video describes a cryptocurrency purchase ...
# 39  The video description contains a message from ...
# 40  The video shows a demonstration of self-defens...
# 41  The video description contains strong signals ...
# 42  The description contains phrases like '아이디Patr...
# 43  The video appears to be a product showcase for...
# 44  The video shows a guaranteed high return on in...
# 45  The video contains strong scam indicators such...
# 46  The video contains strong signals of guarantee...
# 47  The video shows a person explaining something ...
# 48  The video shows a classroom-like environment w...
# 49  The conversation includes references to a spec...
# 50  The video contains strong indicators of a scam...
# 51  The video description mentions a customer's or...
# 52  The video features AI-generated images of a 'd...
# 53  The video description includes a strong call t...
# 54  The description includes a 'must buy' statemen...

# %%
df.groupby(["truth", "result"]).agg({"filename":"count"})
# Out:
#                  filename
# truth    result
# abnormal False         12
#          True          15
# normal   False          2
#          True          26

# %%
df[df['result']==True]
# Out:
#     filename     truth  is_scam  result  confidence  risk  \
# 1   0011.mp4    normal    False    True        0.75   low
# 2   0024.mp4    normal    False    True        0.75   low
# 3   0004.mp4    normal    False    True        0.25   low
# 4   0001.mp4    normal    False    True        0.75   low
# 5   0006.mp4    normal    False    True        0.35   low
# 6   0016.mp4    normal    False    True        0.15   low
# 7   0005.mp4    normal    False    True        0.15   low
# 8   0018.mp4    normal    False    True        0.75   low
# 9   0023.mp4    normal    False    True        0.75   low
# 10  0007.mp4    normal    False    True        0.15   low
# 11  0014.mp4    normal    False    True        0.75   low
# 12  0021.mp4    normal    False    True        0.75   low
# 13  0027.mp4    normal    False    True        0.90   low
# 14  0012.mp4    normal    False    True        0.35   low
# 15  0010.mp4    normal    False    True        0.25   low
# 16  0015.mp4    normal    False    True        0.25   low
# 17  0003.mp4    normal    False    True        0.15   low
# 18  0002.mp4    normal    False    True        0.35   low
# 19  0022.mp4    normal    False    True        0.75   low
# 20  0019.mp4    normal    False    True        0.75   low
# 21  0008.mp4    normal    False    True        0.15   low
# 23  0000.mp4    normal    False    True        0.25   low
# 24  0009.mp4    normal    False    True        0.15   low
# 25  0013.mp4    normal    False    True        0.75   low
# 26  0020.mp4    normal    False    True        0.75   low
# 27  0017.mp4    normal    False    True        0.15   low
# 29  0011.mp4  abnormal     True    True        0.92  high
# 30  0034.mp4  abnormal     True    True        0.95  high
# 31  0029.mp4  abnormal     True    True        0.92  high
# 32  0033.mp4  abnormal     True    True        0.95  high
# 35  0001.mp4  abnormal     True    True        0.92  high
# 36  0006.mp4  abnormal     True    True        0.85  high
# 41  0014.mp4  abnormal     True    True        0.92  high
# 44  0010.mp4  abnormal     True    True        0.92  high
# 45  0003.mp4  abnormal     True    True        0.95  high
# 46  0002.mp4  abnormal     True    True        0.92  high
# 49  0026.mp4  abnormal     True    True        0.92  high
# 50  0032.mp4  abnormal     True    True        0.92  high
# 52  0009.mp4  abnormal     True    True        0.92  high
# 53  0013.mp4  abnormal     True    True        0.92  high
# 54  0017.mp4  abnormal     True    True        0.85  high
#
#                                              evidence  \
# 1               할바하게 되면 하는 것; 이어폰 빼고; 결제카드는; 이걸로 해주세요
# 2   New product innovation; Innovative solution fo...
# 3   Must buy before [date] statements; Suspicious ...
# 4                              2025년 최저임금 인상 확정; 주휴스담
# 5                                          50대 근판리얼후기
# 6            Rubik's cube solving; casual interaction
# 7   No explicit requests for payment or data; No d...
# 8                                                한번씩만
# 9                    non-stick coating; multi-cookpan
# 10                              7일간 단기알바 만으로 100만원 벌기
# 11  Guaranteed or outsized returns/profits; Direct...
# 12  Certification of qualification; Online study a...
# 13  280 calorie ramen; 250 calorie Boston cream; 1...
# 14                                이托리들이; 이거 그iddy한 데요
# 15                                      고객을 만족시켜야 합니다
# 16                                         T1 x Speak
# 17  No explicit requests for payment or data; No d...
# 18                                    MBTI bill; INFP
# 19        NEW 다이슨 슈퍼소닉 r; 다이스의 가장 가벼고, 가장 경력한? 해어트라이어
# 20  End of day liquid nitrogen dumps; Liquid nitro...
# 21                         CURPANG ALBA; CURPANG ALBA
# 23                                         무자로 보내 주셔~
# 24  Coupaing delivery; Scanning packages; Vending ...
# 25               banana milkshake; Compose Coffee cup
# 26                         Hangang Bus; Grand Opening
# 27                              이대생이 시험지를 반대로 집어두는 이유
# 29                                      银行账号; 能听懂我说话吧
# 30  guaranteed or outsized returns; direct request...
# 31  100% guaranteed profit; external contact via K...
# 32  300% guaranteed profit; QR code to join a Tele...
# 35                          ohoo nasda injeong; 6月14일
# 36                                      50만 원씩; 아르바이트
# 41  guaranteed or outsized returns/profits; direct...
# 44                guaranteed return; external contact
# 45  guaranteed or outsized returns; direct request...
# 46  guaranteed or outsized returns/profits; extern...
# 49                                         柏林市長; 特別部隊
# 50               guaranteed returns; external contact
# 52            AI-generated doctor; fake advertisement
# 53               Must buy before June 6th; VIP席 FLOOR
# 54   Must buy before [date]; Install app/site to earn
#
#                                           explanation
# 1   The video appears to be a humorous or instruct...
# 2   The video describes a new, innovative way to c...
# 3   The video appears educational, focusing on a j...
# 4   The video discusses the minimum wage increase ...
# 5   The video description contains a personal stor...
# 6   The video shows a person casually solving a Ru...
# 7   The video appears to be a normal interaction i...
# 8   The video description does not contain any exp...
# 9   The video describes the features of a non-stic...
# 10  The video description does not contain any str...
# 11  The video describes a process of making drinks...
# 12  The video describes a certification process fo...
# 13  The video shows a person eating various meals,...
# 14  The video features a humorous interaction betw...
# 15  The video description contains a message about...
# 16  The video features a collaboration between T1 ...
# 17  The video appears to be a humorous skit from '...
# 18  The video appears to be an educational or info...
# 19  The video describes a new Dyson product withou...
# 20  The video describes the use of liquid nitrogen...
# 21  The video appears to be a personal account of ...
# 23  The video description contains a request to se...
# 24  The video shows a typical day at an e-commerce...
# 25  The video shows the preparation of a banana mi...
# 26  The video describes a public transportation se...
# 27  The video provides a step-by-step guide on how...
# 29  The video contains a direct request for bank a...
# 30  The video contains strong indicators of a scam...
# 31  The video contains strong scam signals such as...
# 32  The description contains explicit profit guara...
# 35  The video contains strong scam signals such as...
# 36  The video description mentions a digital job t...
# 41  The video description contains strong signals ...
# 44  The video shows a guaranteed high return on in...
# 45  The video contains strong scam indicators such...
# 46  The video contains strong signals of guarantee...
# 49  The conversation includes references to a spec...
# 50  The video contains strong indicators of a scam...
# 52  The video features AI-generated images of a 'd...
# 53  The video description includes a strong call t...
# 54  The description includes a 'must buy' statemen...

# %%
df[df['result']==False]
# Out:
#     filename     truth  is_scam  result  confidence  risk  \
# 0   0025.mp4    normal     True   False        0.92  high
# 22  0026.mp4    normal     True   False        0.92  high
# 28  0025.mp4  abnormal    False   False        0.35   low
# 33  0004.mp4  abnormal    False   False        0.75   low
# 34  0035.mp4  abnormal    False   False        0.15   low
# 37  0016.mp4  abnormal    False   False        0.35   low
# 38  0005.mp4  abnormal    False   False        0.35   low
# 39  0018.mp4  abnormal    False   False        0.25   low
# 40  0007.mp4  abnormal    False   False        0.75   low
# 42  0031.mp4  abnormal    False   False        0.35   low
# 43  0012.mp4  abnormal    False   False        0.75   low
# 47  0030.mp4  abnormal    False   False        0.75   low
# 48  0008.mp4  abnormal    False   False        0.35   low
# 51  0000.mp4  abnormal    False   False        0.35   low
#
#                                            evidence  \
# 0                             우버 택시 50% 헤택; 그시절택시요금
# 22                            우버 택시 50% 헤택; 그시절택시요금
# 28                   recommendation code; app usage
# 33         Various sandals displayed; Handbag shown
# 34   10월 전에는 꼭 사라; 보통주 (06★★★) 현제가: 1400 최고가: 32000
# 37                                        2,500,000
# 38          가상화폐 구매대행 모집; 한 달이면 마음에 드는 차를 살 수 있습니다.
# 39                                        다음message
# 40                     사람들에게 공과 희망을; 불어 놓아주는 사이비 교수
# 42                               아이디Patrick; 게임성공추천
# 43                     Gucci brand; product details
# 47                      전천조 고백 나는 사기꾼; 별 걸 다 했어네 진짜
# 48                classroom setting; group activity
# 51  고객님께서 주문하신 남성 패딩 배송전实时사입니다; 예쁜 패딩 필요하신 분们 물어주시면
#
#                                           explanation
# 0   The video contains strong scam signals, such a...
# 22  The video contains strong scam signals, such a...
# 28  The video shows a person discussing an app and...
# 33  The video shows a display of various sandals a...
# 34  The video description contains typical stock m...
# 37  The video contains a large number '2,500,000' ...
# 38  The video describes a cryptocurrency purchase ...
# 39  The video description contains a message from ...
# 40  The video shows a demonstration of self-defens...
# 42  The description contains phrases like '아이디Patr...
# 43  The video appears to be a product showcase for...
# 47  The video shows a person explaining something ...
# 48  The video shows a classroom-like environment w...
# 51  The video description mentions a customer's or...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score, confusion_matrix, ConfusionMatrixDisplay

# abnormal = positive class
df['y_true'] = df['truth'].apply(lambda x: 1 if x=='abnormal' else 0)
y_true = df['y_true'].values
y_scores = df['confidence'].values

# Precision-Recall + AP
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
ap = average_precision_score(y_true, y_scores)
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"AP (mAP): {ap:.4f}")

# PR curve 시각화
plt.figure(figsize=(6,6))
plt.plot(recall, precision, marker='.', label=f'AP={ap:.4f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid()
plt.show()

# 최적 threshold 선택 (F1 최대)
f1_scores = 2*precision*recall/(precision+recall+1e-8)
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
print(f"Optimal threshold (F1 max): {best_threshold:.2f}")

# Confusion matrix
y_pred = (y_scores >= best_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred, labels=[1,0])
disp = ConfusionMatrixDisplay(cm, display_labels=['abnormal', 'normal'])
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Confusion Matrix @ threshold={best_threshold:.2f}')
plt.show()
